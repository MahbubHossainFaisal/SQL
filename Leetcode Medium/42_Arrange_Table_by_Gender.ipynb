# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     with cte as
#     (
#         select * , RANK() OVER(partition by gender ORDER BY user_id) as rnk1,
#         CASE when gender = 'female' then 1 when gender='other' then 2 else 3 as rnk2
#         from Genders
#     )
#
#     select user_id,gender from cte order by rnk1,rnk2
