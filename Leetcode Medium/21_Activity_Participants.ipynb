# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
    with cte as
    (
        Select activity, count(id) as num_part
        from Friends
        Group By activity
    ),
    cte2(
        select a.name,Coalesce(c.num_port,0)
        From Activity a
        Left Join cte c
        on a.name = c.activity
    )
    
    select name
    where num_port <> (select max(num_port) from cte2)
    and num_port <> (select min(num_port) from cte2)
