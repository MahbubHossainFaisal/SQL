# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Query
#
#     Select gender,day, SUM(score_points) OVER(Partition by gender Order by gender,day
#     ROWS BETWEEN UNBOUNDED PRECEEDING AND CURRENT ROW) as total
#     from Scores;
