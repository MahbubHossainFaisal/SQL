# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     select player_id,event_date,
#     sum(games_played)
#     OVER(Partition by player_id Order by event_date ROWS between Unbounded Preceeding and Current ROW)
#     as games_played_so_far
#     From Activity
