# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     with cte as
#     (
#         select *,DAYOFWEEK(submit_date) as day_no from Tasks
#     )
#
#     select sum(case when day_no in (6,7) then 1 else 0) as  weekend_cnt,
#     sum(case when day_no in (1,2,3,4,5) then 1 else 0 end) as working_cnt
#     from cte;
