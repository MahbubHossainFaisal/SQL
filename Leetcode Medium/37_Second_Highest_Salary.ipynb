# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     SELECT
#       CASE WHEN salary > 0 THEN salary ELSE NULL END AS SecondHighestSalary
#     FROM Employee
#     ORDER BY salary DESC
#     LIMIT 1 OFFSET 1;
