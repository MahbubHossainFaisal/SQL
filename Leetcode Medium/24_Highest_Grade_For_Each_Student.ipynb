# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     with cte as
#     (
#         select *, max(grade) over(partition by student_id Order by course_id) as max_grade
#         from Enrollments
#     )
#
#     select student_id,Min(course_id),grade from cte where
#     where grade = max_grade
