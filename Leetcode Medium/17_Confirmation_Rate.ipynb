# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# User 6 did not request any confirmation messages. The confirmation rate is 0.
# User 3 made 2 requests and both timed out. The confirmation rate is 0.
# User 7 made 3 requests and all were confirmed. The confirmation rate is 1.
# User 2 made 2 requests where one was confirmed and the other timed out. The confirmation rate is 1 / 2 = 0.5.

# %% [markdown]
#     with conf as (
#         SELECT x.user_id,y.action from Signups x
#
#         Left join Confirmations y
#         on x.user_id=y.user_id
#     )
#
#     select a.user_id,ROUND(
#       (select count(c.user_id) from conf c
#       where c.action='confirmed' and c.user_id = a.user_id)
#          /
#     (select count(b.user_id) from conf b
#     WHERE b.user_id=a.user_id),2) as confirmation_rate
#
#     from conf a
#     group by a.user_id
