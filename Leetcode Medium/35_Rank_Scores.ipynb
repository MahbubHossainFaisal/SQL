# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     select score,dense_rank() over(order by score desc) as 'rank'
#     from Scores
#     order by score desc
