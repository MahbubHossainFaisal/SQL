# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#     with cte as
#     (
#         select *, avg(occurances) over(partition by event_type) as avg_occurance
#     )
#
#     select business_id from cte
#     where occurances > avg_occurances
#     group by business_id
#     having count(event_type) > 1
